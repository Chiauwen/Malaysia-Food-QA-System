# %%
# %%bash
#
# pip install --upgrade pip
# pip install farm-haystack[colab,preprocessing,elasticsearch]
# Out:
# Couldn't find program: 'bash'

# %%
pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.8.0)
# Requirement already satisfied: elastic-transport<9,>=8 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from elasticsearch) (8.4.0)
# Requirement already satisfied: urllib3<2,>=1.26.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from elastic-transport<9,>=8->elasticsearch) (1.26.14)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from elastic-transport<9,>=8->elasticsearch) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)

# %%
from haystack.telemetry import tutorial_running

tutorial_running(3)

# %%
import logging

logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
logging.getLogger("haystack").setLevel(logging.INFO)

# %%
from haystack.document_stores import InMemoryDocumentStore

document_store = InMemoryDocumentStore(use_bm25=True)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CUDA:0 - Number of GPUs: 1

# %%
from haystack.utils import launch_es
launch_es()
# Out:
# WARNING - haystack.utils.doc_store -  Tried to start Elasticsearch through Docker but this failed. It is likely that there is already an existing Elasticsearch instance running.

# %%
import os
from haystack.document_stores import ElasticsearchDocumentStore

# Get the host where Elasticsearch is running, default to localhost
host = os.environ.get("ELASTICSEARCH_HOST", "localhost")

document_store = ElasticsearchDocumentStore(
    host=host,
    username="",
    password="",
    index="document"
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4 # Get the host where Elasticsearch is running, default to localhost                         │
# │    5 host = os.environ.get("ELASTICSEARCH_HOST", "localhost")                                    │
# │    6                                                                                             │
# │ ❱  7 document_store = ElasticsearchDocumentStore(                                                │
# │    8 │   host=host,                                                                              │
# │    9 │   username="",                                                                            │
# │   10 │   password="",                                                                            │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\base.py:46 in                           │
# │ wrapper_exportable_to_yaml                                                                       │
# │                                                                                                  │
# │    43 │   │   │   │   self._component_config["params"][k] = v                                    │
# │    44 │   │                                                                                      │
# │    45 │   │   # Call the actuall __init__ function with all the arguments                        │
# │ ❱  46 │   │   init_func(self, *args, **kwargs)                                                   │
# │    47 │                                                                                          │
# │    48 │   return wrapper_exportable_to_yaml                                                      │
# │    49                                                                                            │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\document_stores\elasticsearch.py:133 in       │
# │ __init__                                                                                         │
# │                                                                                                  │
# │   130 │   │                                                                                      │
# │   131 │   │   """                                                                                │
# │   132 │   │   # Base constructor might need the client to be ready, create it first              │
# │ ❱ 133 │   │   client = self._init_elastic_client(                                                │
# │   134 │   │   │   host=host,                                                                     │
# │   135 │   │   │   port=port,                                                                     │
# │   136 │   │   │   username=username,                                                             │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\document_stores\elasticsearch.py:247 in       │
# │ _init_elastic_client                                                                             │
# │                                                                                                  │
# │   244 │   │   │   )                                                                              │
# │   245 │   │   else:                                                                              │
# │   246 │   │   │   # there is no authentication for this elasticsearch instance                   │
# │ ❱ 247 │   │   │   client = Elasticsearch(                                                        │
# │   248 │   │   │   │   hosts=hosts,                                                               │
# │   249 │   │   │   │   scheme=scheme,                                                             │
# │   250 │   │   │   │   ca_certs=ca_certs,                                                         │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\generalimport\fake_module.py:19 in error_func          │
# │                                                                                                  │
# │   16 │                                                                                           │
# │   17 │   def error_func(self, *args, **kwargs):                                                  │
# │   18 │   │   name = f"'{self.name}'" if hasattr(self, "name") else ""  # For __class_getitem_    │
# │ ❱ 19 │   │   raise MissingOptionalDependency(f"Optional dependency {name} was used but it isn    │
# │   20 │                                                                                           │
# │   21 │   def __getattr__(self, item):                                                            │
# │   22 │   │   if item in self.non_called_dunders:                                                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# MissingOptionalDependency: Optional dependency 'elasticsearch' was used but it isn't installed.

# %%
from haystack import Pipeline
from haystack.nodes import TextConverter, PreProcessor

indexing_pipeline = Pipeline()
text_converter = TextConverter()
preprocessor = PreProcessor(
    clean_whitespace=True,
    clean_header_footer=True,
    clean_empty_lines=True,
    split_by="word",
    split_length=500,
    split_overlap=20,
    split_respect_sentence_boundary=True,
)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
import os

indexing_pipeline.add_node(component=text_converter, name="TextConverter", inputs=["File"])
indexing_pipeline.add_node(component=preprocessor, name="PreProcessor", inputs=["TextConverter"])
indexing_pipeline.add_node(component=document_store, name="DocumentStore", inputs=["PreProcessor"])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 import os                                                                                    │
# │   2                                                                                              │
# │ ❱ 3 indexing_pipeline.add_node(component=text_converter, name="TextConverter", inputs=["File     │
# │   4 indexing_pipeline.add_node(component=preprocessor, name="PreProcessor", inputs=["TextCon     │
# │   5 indexing_pipeline.add_node(component=document_store, name="DocumentStore", inputs=["PreP     │
# │   6                                                                                              │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\pipelines\base.py:424 in add_node             │
# │                                                                                                  │
# │    421 │   │   component_names.add(name)                                                         │
# │    422 │   │   self._set_sub_component_names(component, component_names=component_names)         │
# │    423 │   │                                                                                     │
# │ ❱  424 │   │   self.graph = _add_node_to_pipeline_graph(                                         │
# │    425 │   │   │   graph=self.graph,                                                             │
# │    426 │   │   │   components=component_definitions,                                             │
# │    427 │   │   │   node={"name": name, "inputs": inputs},                                        │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\pipelines\config.py:423 in                    │
# │ _add_node_to_pipeline_graph                                                                      │
# │                                                                                                  │
# │   420 │   if instance:                                                                           │
# │   421 │   │   existing_node_names = [name for name, data in graph.nodes.items() if data["compo   │
# │   422 │   │   if len(existing_node_names) > 0:                                                   │
# │ ❱ 423 │   │   │   raise PipelineConfigError(                                                     │
# │   424 │   │   │   │   f"Cannot add node '{node['name']}' You have already added the same insta   │
# │   425 │   │   │   │   f"under the name '{existing_node_names[0]}'."                              │
# │   426 │   │   │   )                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# PipelineConfigError: Cannot add node 'TextConverter' You have already added the same instance to the pipeline under
# the name 'TextConverter'.

# %%
from haystack.nodes import BM25Retriever

retriever = BM25Retriever(document_store=document_store)

# %%
from haystack.nodes import FARMReader

#reader = FARMReader(model_name_or_path="malay-huggingface/bert-tiny-bahasa-cased", use_gpu=True)
reader = FARMReader(model_name_or_path="my_model", use_gpu=True)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CUDA:0 - Number of GPUs: 1
# INFO - haystack.modeling.utils -  Using devices: CUDA:0 - Number of GPUs: 1
# INFO - haystack.modeling.model.language_model -   * LOADING MODEL: 'my_model' (Bert)
# INFO - haystack.modeling.model.language_model -  Loaded 'my_model' (Bert model) from local file system.
# INFO - haystack.modeling.model.adaptive_model -  Found files for loading 1 prediction heads
# WARNING - haystack.modeling.model.prediction_head -  Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"training": true, "num_labels": 2, "ph_output_type": "per_token_squad", "model_type": "span_classification", "label_tensor_name": "question_answering_label_ids", "label_list": ["start_token", "end_token"], "metric": "squad", "name": "QuestionAnsweringHead"}
# INFO - haystack.modeling.model.prediction_head -  Loading prediction head from my_model\prediction_head_0.bin
# INFO - haystack.modeling.data_handler.processor -  Initialized processor without tasks. Supply `metric` and `label_list` to the constructor for using the default task or add a custom task later via processor.add_task()
# INFO - haystack.modeling.utils -  Using devices: CUDA:0 - Number of GPUs: 1

# %%
from haystack import Pipeline

querying_pipeline = Pipeline()
querying_pipeline.add_node(component=retriever, name="Retriever", inputs=["Query"])
querying_pipeline.add_node(component=reader, name="Reader", inputs=["Retriever"])

# %%
prediction = querying_pipeline.run(
    query="Apakah makanan tradisional melayu?",
    params={
        "Retriever": {"top_k": 10},
        "Reader": {"top_k": 1}
    }
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\pipelines\base.py:555 in run                  │
# │                                                                                                  │
# │    552 │   │   │   │   try:                                                                      │
# │    553 │   │   │   │   │   logger.debug("Running node '%s` with input: %s", node_id, node_input  │
# │    554 │   │   │   │   │   start = time()                                                        │
# │ ❱  555 │   │   │   │   │   node_output, stream_id = self._run_node(node_id, node_input)          │
# │    556 │   │   │   │   │   if "_debug" in node_output and node_id in node_output["_debug"]:      │
# │    557 │   │   │   │   │   │   node_output["_debug"][node_id]["exec_time_ms"] = round((time() -  │
# │    558 │   │   │   │   except Exception as e:                                                    │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\pipelines\base.py:468 in _run_node            │
# │                                                                                                  │
# │    465 │   │   self.graph.nodes[name]["component"] = component                                   │
# │    466 │                                                                                         │
# │    467 │   def _run_node(self, node_id: str, node_input: Dict[str, Any]) -> Tuple[Dict, str]:    │
# │ ❱  468 │   │   return self.graph.nodes[node_id]["component"]._dispatch_run(**node_input)         │
# │    469 │                                                                                         │
# │    470 │   def run(  # type: ignore                                                              │
# │    471 │   │   self,                                                                             │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\base.py:201 in _dispatch_run            │
# │                                                                                                  │
# │   198 │   │   The Pipelines call this method when run() is executed. This method in turn execu   │
# │   199 │   │   method with the correct run method.                                                │
# │   200 │   │   """                                                                                │
# │ ❱ 201 │   │   return self._dispatch_run_general(self.run, **kwargs)                              │
# │   202 │                                                                                          │
# │   203 │   def _dispatch_run_batch(self, **kwargs):                                               │
# │   204 │   │   """                                                                                │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\base.py:245 in _dispatch_run_general    │
# │                                                                                                  │
# │   242 │   │   │   if key in run_signature_args:                                                  │
# │   243 │   │   │   │   run_inputs[key] = value                                                    │
# │   244 │   │                                                                                      │
# │ ❱ 245 │   │   output, stream = run_method(**run_inputs, **run_params)                            │
# │   246 │   │                                                                                      │
# │   247 │   │   # Collect debug information                                                        │
# │   248 │   │   debug_info = {}                                                                    │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\retriever\base.py:263 in run            │
# │                                                                                                  │
# │   260 │   │   │   │   )                                                                          │
# │   261 │   │   │   self.query_count += 1                                                          │
# │   262 │   │   │   run_query_timed = self.timing(self.run_query, "query_time")                    │
# │ ❱ 263 │   │   │   output, stream = run_query_timed(                                              │
# │   264 │   │   │   │   query=query, filters=filters, top_k=top_k, index=index, headers=headers,   │
# │   265 │   │   │   )                                                                              │
# │   266 │   │   elif root_node == "File":                                                          │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\retriever\base.py:82 in wrapper         │
# │                                                                                                  │
# │    79 │   │   │   if attr_name not in self.__dict__:                                             │
# │    80 │   │   │   │   self.__dict__[attr_name] = 0                                               │
# │    81 │   │   │   tic = perf_counter()                                                           │
# │ ❱  82 │   │   │   ret = fn(*args, **kwargs)                                                      │
# │    83 │   │   │   toc = perf_counter()                                                           │
# │    84 │   │   │   self.__dict__[attr_name] += toc - tic                                          │
# │    85 │   │   │   return ret                                                                     │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\retriever\base.py:317 in run_query      │
# │                                                                                                  │
# │   314 │   │   headers: Optional[Dict[str, str]] = None,                                          │
# │   315 │   │   scale_score: Optional[bool] = None,                                                │
# │   316 │   ):                                                                                     │
# │ ❱ 317 │   │   documents = self.retrieve(                                                         │
# │   318 │   │   │   query=query, filters=filters, top_k=top_k, index=index, headers=headers, sca   │
# │   319 │   │   )                                                                                  │
# │   320 │   │   document_ids = [doc.id for doc in documents]                                       │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\nodes\retriever\sparse.py:228 in retrieve     │
# │                                                                                                  │
# │   225 │   │   if all_terms_must_match is None:                                                   │
# │   226 │   │   │   all_terms_must_match = self.all_terms_must_match                               │
# │   227 │   │                                                                                      │
# │ ❱ 228 │   │   documents = document_store.query(                                                  │
# │   229 │   │   │   query=query,                                                                   │
# │   230 │   │   │   filters=filters,                                                               │
# │   231 │   │   │   top_k=top_k,                                                                   │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\document_stores\memory.py:982 in query        │
# │                                                                                                  │
# │    979 │   │                                                                                     │
# │    980 │   │   index = index or self.index                                                       │
# │    981 │   │   if index not in self.bm25:                                                        │
# │ ❱  982 │   │   │   raise DocumentStoreError(                                                     │
# │    983 │   │   │   │   f"No BM25 representation found for the index: {index}. The Document stor  │
# │    984 │   │   │   )                                                                             │
# │    985                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DocumentStoreError: No BM25 representation found for the index: document. The Document store should be initialized
# with use_bm25=True
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 prediction = querying_pipeline.run(                                                          │
# │   2 │   query="Apakah makanan tradisional melayu?",                                              │
# │   3 │   params={                                                                                 │
# │   4 │   │   "Retriever": {"top_k": 10},                                                          │
# │                                                                                                  │
# │ C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python310\site-packages\haystack\pipelines\base.py:562 in run                  │
# │                                                                                                  │
# │    559 │   │   │   │   │   # The input might be a really large object with thousands of embeddi  │
# │    560 │   │   │   │   │   # If you really want to see it, raise the log level.                  │
# │    561 │   │   │   │   │   logger.debug("Exception while running node '%s' with input %s", node  │
# │ ❱  562 │   │   │   │   │   raise Exception(                                                      │
# │    563 │   │   │   │   │   │   f"Exception while running node '{node_id}': {e}\nEnable debug lo  │
# │    564 │   │   │   │   │   ) from e                                                              │
# │    565 │   │   │   │   queue.pop(node_id)                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# Exception: Exception while running node 'Retriever': No BM25 representation found for the index: document. The
# Document store should be initialized with use_bm25=True
# Enable debug logging to see the data that was passed when the pipeline failed.
